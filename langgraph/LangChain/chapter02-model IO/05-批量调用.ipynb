# %%
import os
from urllib import response

from azure.identity import DefaultAzureCredential, get_bearer_token_provider
from dotenv import find_dotenv, load_dotenv
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_openai import ChatOpenAI

#load_dotenv(find_dotenv(usecwd=True), override=True)
load_dotenv()

AZURE_OPENAI_BASE_URL = os.environ["AZURE_OPENAI_BASE_URL"]
MODEL_NAME = os.environ["MODEL_NAME"]

token_provider = get_bearer_token_provider(
    DefaultAzureCredential(),
    os.environ["AZURE_OPENAI_TOKEN_SCOPE"],
)

chat_model = ChatOpenAI(
    api_key=token_provider,
    base_url=AZURE_OPENAI_BASE_URL,
    model=MODEL_NAME,
    use_responses_api=True,
    streaming=True
)

messages1 = [SystemMessage(content="你是一位乐于助人的智能小助手"),
             HumanMessage(content="请帮我介绍一下什么是机器学习"), ]

messages2 = [SystemMessage(content="你是一位乐于助人的智能小助手"),
             HumanMessage(content="请帮我介绍一下什么是AIGC"), ]

messages3 = [SystemMessage(content="你是一位乐于助人的智能小助手"),
             HumanMessage(content="请帮我介绍一下什么是大模型技术"), ]

messages = [messages1, messages2, messages3]

response = chat_model.batch(messages)

print("批量调用结果：")
for i, res in enumerate(response):
    print(f"第{i + 1}条消息的响应：")
    print(res.text)     
print("批量调用结束")
# Out:
# 批量调用结果：
# 第1条消息的响应：
# 机器学习（Machine Learning，简称 ML）是人工智能的一个重要分支。它让计算机通过数据学习规律，并利用这些规律进行预测、分类或决策，而不需要程序员为每种情况都编写明确规则。
#
# ### 一个简单例子
#
# 如果要让计算机识别垃圾邮件：
#
# - **传统编程**：人工制定规则，例如“包含某些词语的邮件可能是垃圾邮件”。
# - **机器学习**：提供大量标记为“垃圾邮件”或“正常邮件”的样本，让算法自动学习它们的特征和规律，再判断新邮件属于哪一类。
#
# ### 机器学习的主要类型
#
# 1. **监督学习**
#    使用带有正确答案（标签）的数据训练模型。
#    常见任务：图片分类、房价预测、疾病诊断。
#
# 2. **无监督学习**
#    数据没有标签，算法自行发现其中的结构或模式。
#    常见任务：用户分群、异常检测、数据降维。
#
# 3. **强化学习**
#    智能体通过与环境互动，根据奖励或惩罚学习最佳策略。
#    常见应用：游戏 AI、机器人控制、自动驾驶。
#
# ### 基本流程
#
# 机器学习通常包括：
#
# 1. 收集和整理数据
# 2. 提取或选择数据特征
# 3. 选择算法并训练模型
# 4. 使用测试数据评估效果
# 5. 调整和部署模型
# 6. 持续监控与更新
#
# ### 常见应用
#
# - 搜索和内容推荐
# - 人脸与语音识别
# - 垃圾邮件过滤
# - 金融风控和反欺诈
# - 医疗影像分析
# - 自动驾驶
# - 智能客服与自然语言处理
#
# 简单来说，**机器学习就是让计算机从经验（数据）中学习，并在新问题上做出相对准确的判断**。它的效果高度依赖数据质量、算法选择以及训练方式。
# 第2条消息的响应：
# AIGC 是 **AI-Generated Content（人工智能生成内容）** 的缩写，指利用人工智能技术自动或辅助创作文字、图片、音频、视频、代码等内容。
#
# ### 常见的 AIGC 形式
#
# - **文本生成**：写文章、文案、报告、邮件、对话等
# - **图片生成**：根据文字描述生成插画、海报、设计图等
# - **音频生成**：合成语音、音乐、音效或进行声音克隆
# - **视频生成**：生成短视频、数字人、动画或进行智能剪辑
# - **代码生成**：编写、补全、解释和调试程序代码
# - **多模态生成**：同时理解和生成文字、图片、音频、视频等不同形式的内容
#
# ### AIGC 是如何工作的？
#
# AIGC 通常基于大模型和深度学习技术。模型会从大量数据中学习语言规律、图像特征或声音模式。当用户输入指令，也就是常说的 **提示词（Prompt）** 后，模型会根据所学规律生成相应内容。
#
# 例如，输入“写一篇关于低碳生活的短文”，AI 就可以快速生成一篇相关文本；输入“一只宇航员猫站在月球上”，图片生成模型则可以据此创作图像。
#
# ### 主要应用场景
#
# AIGC 已应用于：
#
# - 新闻传媒与内容创作
# - 广告营销与电商文案
# - 教育辅导与知识问答
# - 游戏、影视和动画制作
# - 软件开发与办公自动化
# - 产品设计与创意辅助
# - 智能客服和虚拟数字人
#
# ### AIGC 的优势
#
# - 提高内容生产效率
# - 降低创作和制作成本
# - 帮助普通用户快速表达创意
# - 支持个性化、批量化内容生成
# - 辅助人类进行灵感拓展和决策
#
# ### 需要注意的问题
#
# AIGC 也存在一些风险和局限，例如：
#
# - 可能生成错误或虚构的信息
# - 涉及版权、隐私和数据安全问题
# - 可能被用于制造虚假内容或深度伪造
# - 生成结果可能带有偏见
# - 过度依赖可能削弱独立思考与原创能力
#
# 因此，使用 AIGC 时应对内容进行人工核实，并遵守版权、隐私和相关法律规范。
#
# 简单来说，**AIGC 就是让人工智能成为内容创作助手**。它并不只是替代人类创作，更重要的价值是帮助人们提升效率、扩展创意，并探索新的内容生产方式。
# 第3条消息的响应：
# 大模型技术，通常指以**大规模神经网络**为基础，通过海量数据和强大算力训练出来的人工智能技术。我们常说的“大语言模型”（Large Language Model，LLM），如 GPT、通义千问、文心一言、DeepSeek 等，都是其中的典型代表。
#
# ## 一、为什么叫“大模型”？
#
# “大”主要体现在三个方面：
#
# 1. **参数规模大**
#    模型可能包含数十亿、数百亿甚至更多参数。参数可以理解为模型在训练中学到的“知识连接”。
#
# 2. **训练数据多**
#    训练数据通常涵盖网页、书籍、代码、论文、图片、音频等大量内容。
#
# 3. **计算资源需求高**
#    训练大模型需要大量 GPU、专用芯片和分布式计算资源，有时需要持续数周甚至数月。
#
# ## 二、大模型如何工作？
#
# 以大语言模型为例，它的核心训练方式之一是：根据前面的内容，预测接下来最可能出现的词或字符。
#
# 例如输入：
#
# > “今天天气很好，我们一起去……”
#
# 模型可能预测后面是“公园”“散步”或“郊游”。
#
# 通过在海量文本上反复进行这种训练，模型逐渐掌握了语言规律、知识关联、表达方式以及一定的推理和任务处理能力。
#
# 大多数现代语言模型使用一种名为 **Transformer** 的神经网络架构。它能够分析上下文中不同内容之间的关系，因此比较擅长理解和生成长文本。
#
# ## 三、大模型能做什么？
#
# 常见能力包括：
#
# - **内容生成**：写文章、广告文案、邮件、报告等
# - **问答与知识辅助**：解释概念、整理资料、提供建议
# - **文本处理**：摘要、翻译、分类、信息提取
# - **代码辅助**：生成代码、查找错误、解释程序
# - **逻辑与数据分析**：协助解题、分析表格、归纳规律
# - **智能客服与办公助手**
# - **多模态处理**：理解和生成文字、图片、语音、视频等内容
#
# 其中，“多模态大模型”不仅能处理文字，还可以理解图片、音频或视频。例如，用户上传一张照片后，模型可以描述图片内容或回答相关问题。
#
# ## 四、大模型是怎样获得专业能力的？
#
# 大模型通常会经历几个阶段：
#
# 1. **预训练**
#    使用海量数据学习语言、知识和基本规律。
#
# 2. **指令微调**
#    通过大量“问题—回答”示例，让模型学会按照人类指令完成任务。
#
# 3. **人类反馈对齐**
#    人类对模型回答进行评价，帮助模型生成更有用、更安全的内容。
#
# 4. **领域增强**
#    通过专业数据微调，或者连接企业知识库，使模型适用于医疗、法律、金融、教育等领域。
#
# 5. **工具调用**
#    让模型连接搜索引擎、数据库、计算器或业务系统，从而完成查询、计算和实际操作。
#
# ## 五、大模型和传统人工智能有什么不同？
#
# 传统人工智能往往是“一个模型解决一个任务”，例如专门做人脸识别或垃圾邮件分类。
#
# 大模型则更像一个**通用能力平台**：同一个模型可以通过不同指令完成问答、翻译、写作、编程等多种任务，部分任务甚至不需要单独重新训练。
#
# 不过，大模型并不是真的像人类一样理解和思考。它本质上仍然是在根据训练数据和上下文进行复杂的概率计算。
#
# ## 六、大模型有哪些局限？
#
# 大模型虽然强大，但也存在明显问题：
#
# - **可能产生错误信息**，即所谓“幻觉”
# - **知识可能过时**，除非连接实时搜索或数据库
# - **推理并非始终可靠**
# - **可能受到训练数据偏见影响**
# - **存在隐私、版权和数据安全风险**
# - **训练和运行成本较高**
# - **回答听起来合理，不代表一定正确**
#
# 因此，在医疗、法律、金融等高风险场景中，大模型的输出应由专业人员复核。
#
# ## 七、未来发展方向
#
# 大模型技术正在向以下方向发展：
#
# - 模型能力更强、成本更低
# - 更好地处理文字、图像、语音和视频
# - 支持更长的上下文和更复杂的任务
# - 与搜索、数据库及软件工具深度结合
# - 从“回答问题”发展到能规划并执行任务的**智能体**
# - 在手机、电脑等本地设备上运行
# - 更重视准确性、安全性、隐私保护和可解释性
#
# 简单来说，**大模型是一种通过海量数据和大规模计算训练出的通用人工智能基础模型**。它能够理解和生成多种形式的内容，并作为底层能力支持智能助手、办公软件、教育平台、企业系统等应用。
# 批量调用结束
